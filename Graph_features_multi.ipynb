# %%
from multiprocessing import Process

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import csv
import math

# %%
import igraph
import networkx as nx

# %%
from tqdm import tqdm
from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn import preprocessing

# %%
with open("training_set.txt", "r") as f:
    reader = csv.reader(f)
    training_set  = list(reader)

training_set = [element[0].split(" ") for element in training_set]

with open("testing_set.txt", "r") as f:
    reader = csv.reader(f)
    testing_set  = list(reader)

testing_set = [element[0].split(" ") for element in testing_set]

with open("node_information.csv", "r") as f:
    reader = csv.reader(f)
    node_info  = list(reader)

IDs = [element[0] for element in node_info]

# %%
nodes_train_set = [element[0] for element in training_set] + [element[1] for element in training_set]
nodes_test_set = [element[0] for element in testing_set] + [element[1] for element in testing_set]

# %%
subset = True
ratio = 0.1
subset_indices = random.sample(range(len(training_set)),
                        k=int(round(len(training_set)*ratio)))

if subset:
    training_set = [training_set[i] for i in subset_indices]

# %%
def st_jaccard_similarity(source, target, g):
    nr = len(set(g.neighbors(source)).intersection(set(g.neighbors(target))))
    dr = float(len(set(g.neighbors(source)).union(set(g.neighbors(target)))))
    if dr==0:
        ans=0
    else:
        ans = nr/dr
    return ans


#%%
def st_count_nodes_in_paths(source, target, g):
    s=set(g.subcomponent(source, mode="out"))
    t=set(g.subcomponent(target, mode="in"))
    return(len(s.intersection(t)))


# __Definition of a directed and undirected graphs__

#%%
def dir_undir_graph_creation(dataset):
    G_dir = igraph.Graph(directed=True)
    edges = [(element[0], element[1]) for element in dataset if element[2] == "1"]
    nodes = nodes_train_set
    G_dir.add_vertices(nodes)
    G_dir.add_edges(edges)
    G_undir = G_dir.as_undirected()
    return G_dir, G_undir

# %%
g, g_und = dir_undir_graph_creation(training_set)

# %%
def process_training_1():
    start = 0
    end = int(len(training_set)/2)
    l_source_target = []
    l_st_in_out_degree_product = []
    l_st_common_neighbors = []
    l_st_jaccard_similarity = []
    l_st_count_nodes_in_paths = []
    l_st_shortest_paths_dijkstra = []
    l_st_shortest_paths_dijkstra_und = []
    j = 1
    for i in range(start,end):
        log = 'train_set 1 : ' + str(j+1) + '/' + str(len(training_set[start:end]))
        print(log)
        j = j+1
        source = training_set[i][0]
        target = training_set[i][1]
        l_source_target.append((source, target))

        l_st_in_out_degree_product.append(g.degree(source) * g.degree(target))
        l_st_common_neighbors.append(len(set(g.neighbors(source)).intersection(g.neighbors(target))))
        l_st_jaccard_similarity.append(st_jaccard_similarity(source, target, g))
        l_st_count_nodes_in_paths.append(st_count_nodes_in_paths(source, target, g))
        
        if training_set[i][2] == "1":
            g.delete_edges((source, target))
            g_und.delete_edges((source, target))
        l_st_shortest_paths_dijkstra.append(min(100000, g.shortest_paths_dijkstra(source, target)[0][0]))
        l_st_shortest_paths_dijkstra_und.append(min(100000, g_und.shortest_paths_dijkstra(source, target)[0][0]))

        if training_set[i][2] == "1":
            g.add_edge(source, target)
            g_und.add_edge(source, target)


    feat_training = np.array([
        l_st_in_out_degree_product,
        l_st_common_neighbors,
        l_st_jaccard_similarity,
        l_st_count_nodes_in_paths,
        l_st_shortest_paths_dijkstra,
        l_st_shortest_paths_dijkstra_und
    ]).T

    training_labels = np.array([int(element[2]) for element in training_set])
    np.savetxt('training_graph_features_0_307756.txt', feat_training)
    np.savetxt("training_labels_0_307756.txt", training_labels)
    writer = csv.writer(open("training_nodes_0_307756.csv","w"))
    for row in l_source_target:
         writer.writerow(str(row))
    
    return 'process 1 done'

# %%
def process_training_2():
    start = int(len(training_set)/2)
    end = int(len(training_set)/2) * 2
    l_source_target = []
    l_st_in_out_degree_product = []
    l_st_common_neighbors = []
    l_st_jaccard_similarity = []
    l_st_count_nodes_in_paths = []
    l_st_shortest_paths_dijkstra = []
    l_st_shortest_paths_dijkstra_und = []
    j = 1
    for i in range(start,end):
        
        log = 'train_set 2 : ' + str(j+1) + '/' + str(len(training_set[start:end]))
        j = j+1
        print(log)
        source = training_set[i][0]
        target = training_set[i][1]
        l_source_target.append((source, target))

        l_st_in_out_degree_product.append(g.degree(source) * g.degree(target))
        l_st_common_neighbors.append(len(set(g.neighbors(source)).intersection(g.neighbors(target))))
        l_st_jaccard_similarity.append(st_jaccard_similarity(source, target, g))
        l_st_count_nodes_in_paths.append(st_count_nodes_in_paths(source, target, g))
        
        if training_set[i][2] == "1":
            g.delete_edges((source, target))
            g_und.delete_edges((source, target))
        l_st_shortest_paths_dijkstra.append(min(100000, g.shortest_paths_dijkstra(source, target)[0][0]))
        l_st_shortest_paths_dijkstra_und.append(min(100000, g_und.shortest_paths_dijkstra(source, target)[0][0]))

        if training_set[i][2] == "1":
            g.add_edge(source, target)
            g_und.add_edge(source, target)

    feat_training = np.array([
        l_st_in_out_degree_product,
        l_st_common_neighbors,
        l_st_jaccard_similarity,
        l_st_count_nodes_in_paths,
        l_st_shortest_paths_dijkstra,
        l_st_shortest_paths_dijkstra_und
    ]).T

    training_labels = np.array([int(element[2]) for element in training_set])
    np.savetxt('training_graph_features_307756_615512.txt', feat_training)
    np.savetxt("training_labels_307756_615512.txt", training_labels)
    writer = csv.writer(open("training_nodes_307756_615512.csv","w"))
    for row in l_source_target:
         writer.writerow(str(row))
            
    return 'process 2 done'

# %%
def process_testing():
    l_source_target = []
    l_st_in_out_degree_product = []
    l_st_common_neighbors = []
    l_st_jaccard_similarity = []
    l_st_count_nodes_in_paths = []
    l_st_shortest_paths_dijkstra = []
    l_st_shortest_paths_dijkstra_und = []

    for i in range(len(testing_set)):
        step = 'test set : ' + str(i+1) + '/' + str(len(testing_set))
        print(step)
        source = testing_set[i][0]
        target = testing_set[i][1]

        l_source_target.append((source, target))

        l_st_in_out_degree_product.append(g.degree(source) * g.degree(target))
        l_st_common_neighbors.append(len(set(g.neighbors(source)).intersection(g.neighbors(target))))
        l_st_jaccard_similarity.append(st_jaccard_similarity(source, target, g))
        l_st_count_nodes_in_paths.append(st_count_nodes_in_paths(source, target, g))
        

        l_st_shortest_paths_dijkstra.append(g.shortest_paths_dijkstra(source, target)[0][0])
        l_st_shortest_paths_dijkstra_und.append(g_und.shortest_paths_dijkstra(source, target)[0][0])

    feat_testing = np.array([
        l_st_in_out_degree_product,
        l_st_common_neighbors,
        l_st_jaccard_similarity,
        l_st_count_nodes_in_paths,
        l_st_shortest_paths_dijkstra,
        l_st_shortest_paths_dijkstra_und
    ]).T

    np.savetxt('testing_graph_features_all.txt', feat_testing)
    writer = csv.writer(open("testing_nodes.csv","w"))
    for row in l_source_target:
         writer.writerow(str(row))

    return 'process 3 done'

# %%
if __name__ == '__main__':
    processes = []
    for f in [process_training_1, process_training_2, process_testing]:
        p = Process(target=f)
        p.start()
        processes.append(p)
    
    for p in processes:
        p.join()
# Out:
# test set : 1/32648
# train_set 1 : 2/30775
# train_set 2 : 2/30775
# test set : 2/32648
# train_set 2 : 3/30775
# train_set 1 : 3/30775
# test set : 3/32648
# train_set 2 : 4/30775
# train_set 1 : 4/30775
# test set : 4/32648
# train_set 2 : 5/30775
# train_set 1 : 5/30775
# test set : 5/32648
# train_set 2 : 6/30775
# train_set 1 : 6/30775
# test set : 6/32648
# train_set 2 : 7/30775
# train_set 1 : 7/30775
# test set : 7/32648
# train_set 2 : 8/30775
# train_set 1 : 8/30775
# test set : 8/32648
# train_set 2 : 9/30775
# train_set 1 : 9/30775
# test set : 9/32648
# train_set 2 : 10/30775
# train_set 1 : 10/30775
# test set : 10/32648
# train_set 2 : 11/30775
# test set : 11/32648
# train_set 1 : 11/30775
# train_set 2 : 12/30775
# test set : 12/32648
# train_set 1 : 12/30775
# train_set 2 : 13/30775
# train_set 1 : 13/30775
# test set : 13/32648
# train_set 2 : 14/30775
# test set : 14/32648
# train_set 1 : 14/30775
# train_set 2 : 15/30775
# test set : 15/32648
# train_set 1 : 15/30775
# train_set 2 : 16/30775
# test set : 16/32648
# train_set 1 : 16/30775
# train_set 2 : 17/30775
# test set : 17/32648
# train_set 1 : 17/30775
# test set : 18/32648
# train_set 2 : 18/30775
# train_set 1 : 18/30775
# test set : 19/32648
# train_set 2 : 19/30775
# train_set 1 : 19/30775
# test set : 20/32648
# train_set 2 : 20/30775
# train_set 1 : 20/30775
# test set : 21/32648
# train_set 2 : 21/30775
# train_set 1 : 21/30775
# test set : 22/32648
# train_set 2 : 22/30775
# train_set 1 : 22/30775
# test set : 23/32648
# train_set 2 : 23/30775
# test set : 24/32648
# train_set 1 : 23/30775
# train_set 2 : 24/30775
# test set : 25/32648
# train_set 1 : 24/30775
# train_set 2 : 25/30775
# test set : 26/32648
# train_set 1 : 25/30775
# train_set 2 : 26/30775
# test set : 27/32648
# train_set 1 : 26/30775
# train_set 2 : 27/30775
# test set : 28/32648
# train_set 1 : 27/30775
# test set : 29/32648
# train_set 2 : 28/30775
# train_set 1 : 28/30775
# test set : 30/32648
# train_set 2 : 29/30775
# train_set 1 : 29/30775
# test set : 31/32648
# train_set 2 : 30/30775
# train_set 1 : 30/30775
# test set : 32/32648
# train_set 2 : 31/30775
# train_set 1 : 31/30775
# test set : 33/32648
# train_set 2 : 32/30775
# train_set 1 : 32/30775
# test set : 34/32648
# train_set 2 : 33/30775
# train_set 1 : 33/30775
# test set : 35/32648
# train_set 2 : 34/30775
# train_set 1 : 34/30775
# test set : 36/32648
# train_set 2 : 35/30775
# train_set 1 : 35/30775
# test set : 37/32648
# train_set 2 : 36/30775
# test set : 38/32648
# train_set 1 : 36/30775
# train_set 2 : 37/30775
# test set : 39/32648
# train_set 1 : 37/30775
# train_set 2 : 38/30775
# test set : 40/32648
# train_set 1 : 38/30775
# train_set 2 : 39/30775
# test set : 41/32648
# train_set 1 : 39/30775
# train_set 2 : 40/30775
# test set : 42/32648
# train_set 2 : 41/30775
# train_set 1 : 40/30775
# test set : 43/32648
# train_set 1 : 41/30775
# train_set 2 : 42/30775
# test set : 44/32648
# train_set 1 : 42/30775
# train_set 2 : 43/30775
# test set : 45/32648
# train_set 1 : 43/30775
# train_set 2 : 44/30775
# test set : 46/32648
# train_set 1 : 44/30775
# train_set 2 : 45/30775
# test set : 47/32648
# train_set 1 : 45/30775
# test set : 48/32648
# train_set 2 : 46/30775
# train_set 1 : 46/30775
# test set : 49/32648
# train_set 2 : 47/30775
# train_set 1 : 47/30775
# test set : 50/32648
# train_set 2 : 48/30775
# train_set 1 : 48/30775
# test set : 51/32648
# train_set 2 : 49/30775
# train_set 1 : 49/30775
# test set : 52/32648
# train_set 2 : 50/30775
# train_set 1 : 50/30775
# test set : 53/32648
# train_set 2 : 51/30775
# train_set 1 : 51/30775
# test set : 54/32648
# train_set 2 : 52/30775
# test set : 55/32648
# train_set 1 : 52/30775
# train_set 2 : 53/30775
# test set : 56/32648
# train_set 1 : 53/30775
# train_set 2 : 54/30775
# test set : 57/32648
# train_set 1 : 54/30775
# train_set 2 : 55/30775
# test set : 58/32648
# train_set 1 : 55/30775
# train_set 2 : 56/30775
# test set : 59/32648
# train_set 1 : 56/30775
# train_set 2 : 57/30775
# test set : 60/32648
# train_set 1 : 57/30775
# train_set 2 : 58/30775
# test set : 61/32648
# train_set 1 : 58/30775
# test set : 62/32648
# train_set 2 : 59/30775
# train_set 1 : 59/30775
# test set : 63/32648
# train_set 2 : 60/30775
# train_set 1 : 60/30775
# test set : 64/32648
# train_set 2 : 61/30775
# train_set 1 : 61/30775
# test set : 65/32648
# train_set 2 : 62/30775
# train_set 1 : 62/30775
# test set : 66/32648
# train_set 2 : 63/30775
# train_set 1 : 63/30775
# test set : 67/32648
# train_set 2 : 64/30775
# test set : 68/32648
# train_set 1 : 64/30775
# train_set 2 : 65/30775
# test set : 69/32648
# train_set 1 : 65/30775
# train_set 2 : 66/30775
# test set : 70/32648
# train_set 1 : 66/30775
# train_set 2 : 67/30775
# test set : 71/32648
# train_set 1 : 67/30775
# train_set 2 : 68/30775
# test set : 72/32648
# train_set 1 : 68/30775
# test set : 73/32648
# train_set 2 : 69/30775
# train_set 1 : 69/30775
# test set : 74/32648
# train_set 2 : 70/30775
# train_set 1 : 70/30775
# test set : 75/32648
# train_set 2 : 71/30775
# train_set 1 : 71/30775
# test set : 76/32648
# train_set 2 : 72/30775
# train_set 1 : 72/30775
# test set : 77/32648
# train_set 2 : 73/30775
# train_set 1 : 73/30775
# test set : 78/32648
# train_set 2 : 74/30775
# train_set 1 : 74/30775
# test set : 79/32648
# train_set 2 : 75/30775
# train_set 1 : 75/30775
# test set : 80/32648
# train_set 2 : 76/30775
# train_set 1 : 76/30775
# test set : 81/32648
# train_set 2 : 77/30775
# test set : 82/32648
# train_set 1 : 77/30775
# train_set 2 : 78/30775
# test set : 83/32648
# train_set 1 : 78/30775
# train_set 2 : 79/30775
# test set : 84/32648
# train_set 1 : 79/30775
# train_set 2 : 80/30775
# test set : 85/32648
# train_set 1 : 80/30775
# train_set 2 : 81/30775
# test set : 86/32648
# train_set 2 : 82/30775
# train_set 1 : 81/30775
# test set : 87/32648
# train_set 2 : 83/30775
# train_set 1 : 82/30775
# test set : 88/32648
# train_set 2 : 84/30775
# test set : 89/32648
# train_set 1 : 83/30775
# train_set 2 : 85/30775
# test set : 90/32648
# train_set 1 : 84/30775
# train_set 2 : 86/30775
# test set : 91/32648
# train_set 1 : 85/30775
